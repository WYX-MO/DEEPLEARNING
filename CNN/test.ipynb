# %%
import pickle
from pathlib import Path 

base_dir = Path(__file__).getparent()
with open('base_dir/data/data_batch_1','rb') as f:
    data = pickle.load(f, encoding='bytes')

print(pickle.load(f, encoding='bytes'))
